# %%
import pandas as pd

# %%
vehicle_df = pd.read_csv("vehicle_trade_data.csv")

# %%
vehicle_df
# Out:
#        public_reference   mileage reg_code standard_colour  standard_make  \
# 0       202010014440649   31534.0       17            Grey           MINI
# 1       202010155026725   52023.0       66            Blue     Volkswagen
# 2       202008142485309   29500.0       12            Grey  Mercedes-Benz
# 3       202009183894045   35300.0       18            Grey       Vauxhall
# 4       202010014441671   47299.0       65           Black         Nissan
# ...                 ...       ...      ...             ...            ...
# 96264   202010295556637   28225.0       17           White  Mercedes-Benz
# 96265   202010305614799  122000.0       07          Silver            BMW
# 96266   202010315639231   45000.0       15          Silver       Vauxhall
# 96267   202010315647416    4075.0       69            Grey         Nissan
# 96268   202010315659271   52760.0       62           White         Nissan
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
vehicle_df["standard_make"]
# Out:
# 0                 MINI
# 1           Volkswagen
# 2        Mercedes-Benz
# 3             Vauxhall
# 4               Nissan
#              ...
# 96264    Mercedes-Benz
# 96265              BMW
# 96266         Vauxhall
# 96267           Nissan
# 96268           Nissan
# Name: standard_make, Length: 96269, dtype: object

# %%
df1= vehicle_df[vehicle_df["standard_make"]== "BMW"]
df2 = vehicle_df[vehicle_df["standard_make"]== "MINI"]



df3 = vehicle_df[vehicle_df["standard_make"] == "Mercedes-Benz"]
df4 = vehicle_df[vehicle_df["standard_make"] == "Volkswagen"]
df5 = vehicle_df[vehicle_df["standard_make"] == "Vauxhall"]
df6 = vehicle_df[vehicle_df["standard_make"] == "Nissan"]
df7 = vehicle_df[vehicle_df["standard_make"] == "Audi"]
df8 = vehicle_df[vehicle_df["standard_make"] == "Kia"]
df9 = vehicle_df[vehicle_df["standard_make"] == "Renault"]
df10 = vehicle_df[vehicle_df["standard_make"] == "Flat"]
df11 = vehicle_df[vehicle_df["standard_make"] == "Toyota"]
df11
# Out:
#        public_reference   mileage reg_code standard_colour standard_make  \
# 5       202010235355785    7990.0       19           Black        Toyota
# 72      202010285535376    6506.0       68            Blue        Toyota
# 177     202009173855614   15250.0       68            Grey        Toyota
# 379     202010265459337    8020.0       19            Grey        Toyota
# 382     202010285525838   12023.0       66            Blue        Toyota
# ...                 ...       ...      ...             ...           ...
# 95824   202010155047604    2450.0       69            Grey        Toyota
# 95877   202009214013367   11409.0       67           Black        Toyota
# 96007   202010205233970  161000.0       10           Black        Toyota
# 96166   202010195182595    3918.0       20            Grey        Toyota
# 96189   202011015664903  120000.0       55          Silver        Toyota
#
#       standard_model vehicle_condition  year_of_registration  price  \
# ...

# %%
with pd.ExcelWriter('excel_sheets.xlsx') as writer:
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24180/641083312.py in <module>
# ----> 1 excel_df = pd.write_excel("test_sheet.xlsx", sheet_name="standard_make")
#       2 excel_df
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'write_excel'
